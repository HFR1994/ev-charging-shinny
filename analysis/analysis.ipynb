# %%
import json

import numpy as np

from app import utilization_data
from src.shared import get_data_from_api
import pandas as pd

# %%
raw_data = get_data_from_api()
raw_df  = pd.json_normalize(raw_data["chargingStations"])

raw_df.head(5)
# Out:
#               id                   name               address  \
# 0  B8S7YSLRUBVUO       Agerbæk Børnehus           Debelvej 25
# 1  B9OXSNAF20Z5S           Agerbæk Torv         Fåborgvej 177
# 2     Alnasenter            Alna Senter       Strømsveien 245
# 3  B8GEWDTNZ8LXC  Alstad Kro og Camping              Alstad 1
# 4  BA3I6G2IEG4CG                Altdorf  Prackenfelser Str. 8
#
#                                          description  totalConnectors  \
# 0                          Parkering ved børnehuset.                4
# 1                                               None                4
# 2  Lynladere i 1 etg utendørs parkeringshus ved M...               17
# 3                                               None                8
# 4                                               None                8
#
#                                            amenities  location.lat  \
# 0                                                 []     55.603490
# 1                                   [SHOPPING, CAFE]     55.600484
# 2                         [RESTROOM, SHOPPING, CAFE]     59.926581
# 3  [RESTROOM, REST_STOP, RESTAURANT, ACCOMMODATIO...     68.272286
# 4  [RESTROOM, RESTAURANT, SHOPPING, WIFI, CAFE, C...     49.381735
#
#    location.lng                               connectionsTypes.CCS  \
# 0      8.811343                                                 []
# 1      8.802200  [{'id': 'ABT1-A', 'status': 'AVAILABLE', 'effe...
# 2     10.849327  [{'id': 'AL1-1', 'status': 'AVAILABLE', 'effec...
# 3     13.936212  [{'id': 'ALC1-1', 'status': 'AVAILABLE', 'effe...
# 4     11.344057  [{'id': 'ALT1-A', 'status': 'AVAILABLE', 'effe...
#
#                           connectionsTypes.AC Type 2  \
# 0  [{'id': 'AGB1', 'status': 'AVAILABLE', 'effect...
# 1                                                 []
# 2  [{'id': 'AL10', 'status': 'AVAILABLE', 'effect...
# 3  [{'id': 'ALC3-1', 'status': 'AVAILABLE', 'effe...
# 4                                                 []
#
#                             connectionsTypes.CHAdeMO
# 0                                                 []
# 1                                                 []
# 2  [{'id': 'AL1-2', 'status': 'UNAVAILABLE', 'eff...
# 3  [{'id': 'ALC1-2', 'status': 'AVAILABLE', 'effe...
# 4                                                 []

# %%
charging_data = raw_df[
        ['id', 'name', 'address', 'description', 'location.lat', 'location.lng', 'amenities']].copy()

charging_data = charging_data.rename({"location.lat": "latitud", "location.lng": "longitud"}, axis=1)

charging_data.head(5)
# Out:
#               id                   name               address  \
# 0  B8S7YSLRUBVUO       Agerbæk Børnehus           Debelvej 25
# 1  B9OXSNAF20Z5S           Agerbæk Torv         Fåborgvej 177
# 2     Alnasenter            Alna Senter       Strømsveien 245
# 3  B8GEWDTNZ8LXC  Alstad Kro og Camping              Alstad 1
# 4  BA3I6G2IEG4CG                Altdorf  Prackenfelser Str. 8
#
#                                          description    latitud   longitud  \
# 0                          Parkering ved børnehuset.  55.603490   8.811343
# 1                                               None  55.600484   8.802200
# 2  Lynladere i 1 etg utendørs parkeringshus ved M...  59.926581  10.849327
# 3                                               None  68.272286  13.936212
# 4                                               None  49.381735  11.344057
#
#                                            amenities
# 0                                                 []
# 1                                   [SHOPPING, CAFE]
# 2                         [RESTROOM, SHOPPING, CAFE]
# 3  [RESTROOM, REST_STOP, RESTAURANT, ACCOMMODATIO...
# 4  [RESTROOM, RESTAURANT, SHOPPING, WIFI, CAFE, C...

# %%
# Different tariff definitions
#  - kr 5,39/kWh
#  - kr 5,39 / kWh
#  - kr 4,29 per kWh
#  - EUR 0.55 per kWh
#  - 5,49 SEK per kWh
#  - 4,29 kr/kWh + 0 kr/min
#  - kr 5,99/kWh. Over 80%: + kr 1/minutt

conn_cols = [c for c in raw_df.columns if c.startswith("connectionsTypes.")]

tariff_types = []
for _, row in raw_df.iterrows():
    station_id = row["id"]

    for col in conn_cols:
        conn_type = col.split(".", 1)[1]  # extract column type

        connectors = row[col] or []  # each is a list of dicts

        for item in connectors:
            tariff_types.append(
                {
                    "station_id": station_id,
                    "id": item["id"],
                    "connection_type": conn_type,
                    "tariff": item["tariffDefinition"]
                }
            )

tariff_df = pd.DataFrame(tariff_types)
tariff_df.head(5)
# Out:
#       station_id      id connection_type            tariff
# 0  B8S7YSLRUBVUO    AGB1       AC Type 2  DKK 2.69 per kWh
# 1  B8S7YSLRUBVUO    AGB2       AC Type 2  DKK 2.69 per kWh
# 2  B8S7YSLRUBVUO    AGB3       AC Type 2  DKK 2.69 per kWh
# 3  B8S7YSLRUBVUO    AGB4       AC Type 2  DKK 2.69 per kWh
# 4  B9OXSNAF20Z5S  ABT1-A             CCS  DKK 2,99 per kWh

# %%
# In Norway, MVA = Merverdiavgift, which means Value-Added Tax (VAT).

# It is a 25% tax added to most goods and services.
# On EV charging invoices or tariffs, “inkl. MVA” means VAT included.
# “eks. MVA” means VAT excluded.

# Example:
# 5,39 kr/kWh inkl. MVA → final price.
# 5,39 kr/kWh eks. MVA → the station will add +25%.

# Lading for Brim Explorer -> Marine Charging
# Assumes AC and DC current
#   - AC = AC 4,29 kr/kWh
#   - AC = DC 5,39 Kr/kWh

tariff_df["tariff"].unique()
# Out:
# array(['DKK 2.69 per kWh', 'DKK 2,99 per kWh', 'kr 5,39/kWh',
#        'kr 4,29 per kWh', 'kr 5,39 / kWh', 'kr 4,29/kWh',
#        'EUR 0.55 per kWh', 'kr 5,99/kWh. Over 80%: + kr 1/minutt',
#        '5,49 SEK per kWh', '3,39 SEK per kWh', 'kr 3.99 per kWh',
#        'kr 3,99 per kWh', 'DC 5,39 kr/kWh + 1kr/min over 80%',
#        'AC 4,29 kr/kWh', 'kr 2,5 per kWh',
#        'Dynamic. Current price: kr 0,0 per kWh', 'kr 0 per kWh',
#        'DC 5,39 Kr/kWh + 1kr/min over 80%', '4,29 kr/kWh + 0 kr/min',
#        '4,0 kr/kWh + MVA, hurtiglading Lofoten',
#        'kr 2,80 per kWh + MVA, Landstrøm Lofoten',
#        'Lading for Brim Explorer'], dtype=object)

# %%
# From the analysis we can divide the tarifff column into 7 columns:
# - Price
# - Currency (ej: kr)
# - Measurement (ej: kWh)
# - Has extra tarifff (ej: Over 80%: + kr 1/minutt)
# - Has VAT (4,0 kr/kWh + MVA, hurtiglading Lofoten), default to false
# - VAT Location (ej: hurtiglading Lofoten)

# We can drop Marine Charging
# We can assume prices are dynamically changing.

# Doesn't have a number
extracted = tariff_df["tariff"].str.extract(r'(\d+[.,]?\d*)')[0]
tariff_df = tariff_df[extracted.notna()]

# Extract price and remove the ones that are 0
tariff_df["price"] = tariff_df["tariff"].str.extract(r'(\d+[.,]?\d*)')[0].str.replace(",", ".", regex=False).astype(float)
tariff_df = tariff_df[tariff_df["price"] != 0]

tariff_df["measurement"] = tariff_df["tariff"].str.extract(r'(kWh|MWh|Wh)')

# %%
def split_tariff(tariff_item: pd.Series):
    """
    Computes the required properties for a given tariff definition.

    Args:
        tariff_item (pd.Series): Current tariff definition.

    Returns:
        pd.Series: The computed values to add.
    """

    properties = {}
    tariff = tariff_item["tariff"]

    # Check all possible indexes or divisions (. and =)
    plus_index = tariff.find("+")
    new_line_index = tariff.find(". ")
    candidates = [i for i in [plus_index, new_line_index] if i != -1]

    # Which is closer to the start of the string?
    properties["tariff"] = tariff[0:min(candidates)] if candidates else tariff
    properties["extra_tariff"] = tariff[min(candidates)+1:].strip() if candidates else None

    return pd.Series(properties)

tariff_df[["tariff", "extra_tariff"]] = tariff_df.apply(split_tariff, axis=1)
tariff_df["currency"] = tariff_df["tariff"].str.extract(r'(DKK|kr|EUR|SEK)')

# %%
# Still need to check if it has MVA (tax)
tariff_df["extra_tariff"].unique()
# Out:
# array([None, 'Over 80%: + kr 1/minutt', '1kr/min over 80%', '0 kr/min',
#        'MVA, hurtiglading Lofoten', 'MVA, Landstrøm Lofoten'],
#       dtype=object)

# %%
def split_vat(tariff_item: pd.Series):
    """
    Computes the required properties for a given tariff definition.

    Args:
        tariff_item (pd.Series): Current tariff definition.

    Returns:
        pd.Series: The computed values to add.
    """

    properties = {}
    tariff = tariff_item["extra_tariff"]

    properties["has_vat"] = bool(tariff and "MVA" in tariff)
    properties["vat_location"] = tariff.split("MVA,")[1].strip() if properties["has_vat"] else None
    properties["extra_tariff"] = None if properties["has_vat"] else tariff

    return pd.Series(properties)


tariff_df[["has_vat", "vat_location", "extra_tariff"]] = tariff_df.apply(split_vat, axis=1)

# %%
tariff_df.head(10)
# Out:
#       station_id      id connection_type            tariff  price measurement  \
# 0  B8S7YSLRUBVUO    AGB1       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 1  B8S7YSLRUBVUO    AGB2       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 2  B8S7YSLRUBVUO    AGB3       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 3  B8S7YSLRUBVUO    AGB4       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 4  B9OXSNAF20Z5S  ABT1-A             CCS  DKK 2,99 per kWh   2.99         kWh
# 5  B9OXSNAF20Z5S  ABT1-B             CCS  DKK 2,99 per kWh   2.99         kWh
# 6  B9OXSNAF20Z5S  ABT2-A             CCS  DKK 2,99 per kWh   2.99         kWh
# 7  B9OXSNAF20Z5S  ABT2-B             CCS  DKK 2,99 per kWh   2.99         kWh
# 8     Alnasenter   AL1-1             CCS       kr 5,39/kWh   5.39         kWh
# 9     Alnasenter   AL1-3             CCS       kr 5,39/kWh   5.39         kWh
#
#   extra_tariff currency  has_vat vat_location
# 0         None      DKK    False         None
# 1         None      DKK    False         None
# 2         None      DKK    False         None
# 3         None      DKK    False         None
# 4         None      DKK    False         None
# 5         None      DKK    False         None
# 6         None      DKK    False         None
# 7         None      DKK    False         None
# 8         None       kr    False         None
# 9         None       kr    False         None

# %%
charging_data.head(5)
# Out:
#               id                   name               address  \
# 0  B8S7YSLRUBVUO       Agerbæk Børnehus           Debelvej 25
# 1  B9OXSNAF20Z5S           Agerbæk Torv         Fåborgvej 177
# 2     Alnasenter            Alna Senter       Strømsveien 245
# 3  B8GEWDTNZ8LXC  Alstad Kro og Camping              Alstad 1
# 4  BA3I6G2IEG4CG                Altdorf  Prackenfelser Str. 8
#
#                                          description    latitud   longitud  \
# 0                          Parkering ved børnehuset.  55.603490   8.811343
# 1                                               None  55.600484   8.802200
# 2  Lynladere i 1 etg utendørs parkeringshus ved M...  59.926581  10.849327
# 3                                               None  68.272286  13.936212
# 4                                               None  49.381735  11.344057
#
#                                            amenities
# 0                                                 []
# 1                                   [SHOPPING, CAFE]
# 2                         [RESTROOM, SHOPPING, CAFE]
# 3  [RESTROOM, REST_STOP, RESTAURANT, ACCOMMODATIO...
# 4  [RESTROOM, RESTAURANT, SHOPPING, WIFI, CAFE, C...

# %%
# Add some random timestamps to simulate price history between 20 days ago and now
end = pd.Timestamp.now()
start = end - pd.Timedelta(days=20)

# total seconds in the range
total_seconds = int((end - start).total_seconds())

# generate random timestamps
random_ts = start + pd.to_timedelta(
    np.random.randint(0, total_seconds, size=len(tariff_df)),
    unit="s"
)

# convert to UNIX timestamp (seconds)
tariff_df["timestamp"] = random_ts.view("int64") // 10**9

# %%
tariff_df.head(10)
# Out:
#       station_id      id connection_type            tariff  price measurement  \
# 0  B8S7YSLRUBVUO    AGB1       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 1  B8S7YSLRUBVUO    AGB2       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 2  B8S7YSLRUBVUO    AGB3       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 3  B8S7YSLRUBVUO    AGB4       AC Type 2  DKK 2.69 per kWh   2.69         kWh
# 4  B9OXSNAF20Z5S  ABT1-A             CCS  DKK 2,99 per kWh   2.99         kWh
# 5  B9OXSNAF20Z5S  ABT1-B             CCS  DKK 2,99 per kWh   2.99         kWh
# 6  B9OXSNAF20Z5S  ABT2-A             CCS  DKK 2,99 per kWh   2.99         kWh
# 7  B9OXSNAF20Z5S  ABT2-B             CCS  DKK 2,99 per kWh   2.99         kWh
# 8     Alnasenter   AL1-1             CCS       kr 5,39/kWh   5.39         kWh
# 9     Alnasenter   AL1-3             CCS       kr 5,39/kWh   5.39         kWh
#
#   extra_tariff currency  has_vat vat_location   timestamp
# 0         None      DKK    False         None  1764524942
# 1         None      DKK    False         None  1763361325
# 2         None      DKK    False         None  1763166049
# 3         None      DKK    False         None  1764723976
# 4         None      DKK    False         None  1763315028
# 5         None      DKK    False         None  1764201552
# 6         None      DKK    False         None  1764099127
# 7         None      DKK    False         None  1764844287
# 8         None       kr    False         None  1764692819
# 9         None       kr    False         None  1763999168

# %%
filtered = charging_data[charging_data["id"].isin(tariff_df["station_id"].unique())]

print(f"Started with {charging_data["id"].nunique()} stations")
print(f"Left with {filtered["id"].nunique()} stations after removing invalid filters")
# Out:
# Started with 487 stations
# Left with 482 stations

# %%
export_csv = tariff_df[["station_id", "connection_type", "id", "price", "measurement", "extra_tariff", "currency", "has_vat", "vat_location", "timestamp"]]

export_csv.to_csv("../assets/tariff_historical.csv", index=False, encoding="utf-8")

# %%
charging_data.to_csv("../assets/charging_stations.csv", index=False, encoding="utf-8")

# %%
selected_amenities = ["RESTROOM"]
charging_data[charging_data["amenities"].apply(lambda lst: any(a in lst for a in selected_amenities))]
# Out:
#                  id                   name                  address  \
# 2        Alnasenter            Alna Senter          Strømsveien 245
# 3     B8GEWDTNZ8LXC  Alstad Kro og Camping                 Alstad 1
# 4     BA3I6G2IEG4CG                Altdorf     Prackenfelser Str. 8
# 5    Alti-Brotorvet         Alti Brotorvet             Gangveien 10
# 6     BAKY63AK4WMWW    Alti Farmandstredet         Jernbanegaten 1D
# ..              ...                    ...                      ...
# 479   B8CDEXTMW9CLC              Östersund            Arenavägen 19
# 480   B9I7P9R4B24U8              Östhammar           Energivägen 2
# 483   BAKQOLRXNR8QO                Ørebekk           Mosseveien 109
# 485          Oyrane   Øyrane Senter, Førde            Firdavegen 20
# 486         Øystese                Øystese  Hardangerfjordvegen 615
#
#                                            description    latitud   longitud  \
# 2    Lynladere i 1 etg utendørs parkeringshus ved M...  59.926581  10.849327
# 3                                                 None  68.272286  13.936212
# 4                                                 None  49.381735  11.344057
# 5                                                 None  59.046011   9.694568
# 6    Ladestasjonen er i øverste etasje i parkerings...  59.269250  10.413556
# ..                                                 ...        ...        ...
# 479                                 ICA Maxi Östersund  63.192071  14.652091
# 480                          ICA Supermarket Östhammar  60.249628  18.349452
# 483                                               None  59.232266  10.904158
# 485                                               None  61.457726   5.849593
# 486                                               None  60.387014   6.201417
#
#                                              amenities
# 2                           [RESTROOM, SHOPPING, CAFE]
# 3    [RESTROOM, REST_STOP, RESTAURANT, ACCOMMODATIO...
# 4    [RESTROOM, RESTAURANT, SHOPPING, WIFI, CAFE, C...
# 5               [RESTROOM, RESTAURANT, SHOPPING, CAFE]
# 6               [RESTROOM, RESTAURANT, SHOPPING, CAFE]
# ..                                                 ...
# 479  [RESTROOM, REST_STOP, RESTAURANT, SHOPPING, CA...
# 480                               [RESTROOM, SHOPPING]
# 483                  [RESTROOM, SHOPPING, CAR_TRAILER]
# 485            [RESTROOM, SHOPPING, CAFE, CAR_TRAILER]
# 486  [RESTROOM, RESTAURANT, ACCOMMODATION, SHOPPING...
#
# [384 rows x 7 columns]

# %%
connectors = export_csv.groupby("station_id")["id"].nunique()
data = export_csv[export_csv["station_id"].isin(connectors[connectors <= 5].index)]

# %%
int(data.groupby("station_id")["id"].nunique().max())
# Out:
# 5

# %%
data.empty
# Out:
# False

# %%
charging_data["id"].nunique()
# Out:
# 487

# %%
export_csv.head(10)
# Out:
#       station_id connection_type      id  price measurement extra_tariff  \
# 0  B8S7YSLRUBVUO       AC Type 2    AGB1   2.69         kWh         None
# 1  B8S7YSLRUBVUO       AC Type 2    AGB2   2.69         kWh         None
# 2  B8S7YSLRUBVUO       AC Type 2    AGB3   2.69         kWh         None
# 3  B8S7YSLRUBVUO       AC Type 2    AGB4   2.69         kWh         None
# 4  B9OXSNAF20Z5S             CCS  ABT1-A   2.99         kWh         None
# 5  B9OXSNAF20Z5S             CCS  ABT1-B   2.99         kWh         None
# 6  B9OXSNAF20Z5S             CCS  ABT2-A   2.99         kWh         None
# 7  B9OXSNAF20Z5S             CCS  ABT2-B   2.99         kWh         None
# 8     Alnasenter             CCS   AL1-1   5.39         kWh         None
# 9     Alnasenter             CCS   AL1-3   5.39         kWh         None
#
#   currency  has_vat vat_location   timestamp
# 0      DKK    False         None  1764524942
# 1      DKK    False         None  1763361325
# 2      DKK    False         None  1763166049
# 3      DKK    False         None  1764723976
# 4      DKK    False         None  1763315028
# 5      DKK    False         None  1764201552
# 6      DKK    False         None  1764099127
# 7      DKK    False         None  1764844287
# 8       kr    False         None  1764692819
# 9       kr    False         None  1763999168

# %%
raw_df[raw_df["id"] == "Demo stolper"]["connectionsTypes.AC Type 2"][302]
# Out:
# [{'id': 'DEMO-04',
#   'status': 'AVAILABLE',
#   'effect': 22,
#   'tariffDefinition': 'kr 0 per kWh'},
#  {'id': 'DEMO-03',
#   'status': 'AVAILABLE',
#   'effect': 22,
#   'tariffDefinition': 'kr 0 per kWh'}]
